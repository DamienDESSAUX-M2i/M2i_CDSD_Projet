# %% [markdown]
# # Analyse exploratoire

# %%
import sys
from pathlib import Path

APP_DIR = Path.cwd().parent
sys.path.append(APP_DIR.as_posix())

# %%
from src.storages import MinIOStorage

minio = MinIOStorage()
minio.get_storage_stats()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.storages import MinIOStorage
#       3 minio = MinIOStorage()
#       4 minio.get_storage_stats()
#
# File c:\Users/Administrateur/Documents/M2i_Projet_CDSD/app\src\storages\__init__.py:1
# ----> 1 from .minio_storage import MinIOStorage
#       2 from .mongo_storage import MongoStorage
#       3 from .postgresql_storage import PostgresStorage
#
# File c:\Users/Administrateur/Documents/M2i_Projet_CDSD/app\src\storages\minio_storage.py:12
#      10 import soundfile as sf
#      11 from config import minio_config
# ---> 12 from minio.datatypes import Object
#      13 from minio.error import S3Error
#      15 from minio import Minio
#
# File c:\Users\Administrateur\Documents\M2i_Projet_CDSD\.venv\Lib\site-packages\minio\__init__.py:45
#      43 from .error import S3Error as S3Error
#      44 from .error import ServerError as ServerError
# ---> 45 from .minioadmin import MinioAdmin as MinioAdmin
#
# File c:\Users\Administrateur\Documents\M2i_Projet_CDSD\.venv\Lib\site-packages\minio\minioadmin.py:45
#      43 from . import time
#      44 from .credentials import Provider
# ---> 45 from .crypto import decrypt, encrypt
#      46 from .datatypes import PeerInfo, PeerSite, SiteReplicationStatusOptions
#      47 from .error import MinioAdminException
#
# File c:\Users\Administrateur\Documents\M2i_Projet_CDSD\.venv\Lib\site-packages\minio\crypto.py:24
#      21 import os
#      23 from argon2.low_level import Type, hash_secret_raw
# ---> 24 from Crypto.Cipher import AES, ChaCha20_Poly1305
#      25 from Crypto.Cipher._mode_gcm import GcmMode
#      26 from Crypto.Cipher.ChaCha20_Poly1305 import ChaCha20Poly1305Cipher
#
# File c:\Users\Administrateur\Documents\M2i_Projet_CDSD\.venv\Lib\site-packages\Crypto\Cipher\AES.py:71
#      69     _raw_aesni_lib = None
#      70     if _cpu_features.have_aes_ni():
# ---> 71         _raw_aesni_lib = load_pycryptodome_raw_lib("Crypto.Cipher._raw_aesni",
#      72                                                    _cproto.replace("AES",
#      73                                                                    "AESNI"))
#      74 # _raw_aesni may not have been compiled in
#      75 except OSError:
#
# File c:\Users\Administrateur\Documents\M2i_Projet_CDSD\.venv\Lib\site-packages\Crypto\Util\_raw_api.py:312, in load_pycryptodome_raw_lib(name, cdecl)
#     310         attempts.append("Not found '%s'" % filename)
#     311         continue
# --> 312     return load_lib(full_name, cdecl)
#     313 except OSError as exp:
#     314     attempts.append("Cannot load '%s': %s" % (filename, str(exp)))
#
# File c:\Users\Administrateur\Documents\M2i_Projet_CDSD\.venv\Lib\site-packages\Crypto\Util\_raw_api.py:196, in load_lib(name, cdecl)
#     194         raise OSError("Cannot load library '%s'" % name)
#     195     name = full_name
# --> 196 return CDLL(name)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.9-windows-x86_64-none\Lib\ctypes\__init__.py:390, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     387 self._FuncPtr = _FuncPtr
#     389 if handle is None:
# --> 390     self._handle = _dlopen(self._name, mode)
#     391 else:
#     392     self._handle = handle
#
# KeyboardInterrupt:
